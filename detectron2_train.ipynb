# %% [markdown]
# # Detectron2 terminal training

# %%
# !python3 tools/train_net.py \
--num-gpus 2 \
--config-file configs/COCO-InstanceSegmentation/mask_rcnn_R_50_C4_1x.yaml \
SOLVER.IMS_PER_BATCH 4 \
OUTPUT_DIR "logs/mask_rcnn_R_50_C4_1x" \
DATASETS.TRAIN "('voucher_train',)" \
DATASETS.TEST "('voucher_val',)" \
DATALOADER.NUM_WORKERS 16 \
INPUT.CROP.SIZE "[1.0, 1.0]" \
MODEL.ROI_HEADS.NUM_CLASSES 10 \
CUDNN_BENCHMARK True
# Out:
# Command Line Args: Namespace(config_file='configs/COCO-InstanceSegmentation/mask_rcnn_R_50_C4_1x.yaml', dist_url='tcp://127.0.0.1:49152', eval_only=False, machine_rank=0, num_gpus=2, num_machines=1, opts=['SOLVER.IMS_PER_BATCH', '4', 'OUTPUT_DIR', 'logs/mask_rcnn_R_50_C4_1x', 'DATASETS.TRAIN', "('voucher_train',)", 'DATASETS.TEST', "('voucher_val',)", 'DATALOADER.NUM_WORKERS', '16', 'INPUT.CROP.SIZE', '[1.0, 1.0]', 'MODEL.ROI_HEADS.NUM_CLASSES', '10', 'CUDNN_BENCHMARK', 'True'], resume=False)
# [06/05 01:17:08 detectron2]: Rank of current process: 0. World size: 2
# [06/05 01:17:09 detectron2]: Environment info:
# ------------------------  -------------------------------------------------------------
# sys.platform              linux
# Python                    3.6.9 (default, Nov  7 2019, 10:44:02) [GCC 8.3.0]
# numpy                     1.18.4
# detectron2                0.1.2 @/detectron2_repo/detectron2
# detectron2 compiler       GCC 7.5
# detectron2 CUDA compiler  10.1
# ...

# %%
# !python3 tools/train_net.py \
--num-gpus 2 \
--config-file configs/COCO-InstanceSegmentation/mask_rcnn_R_50_C4_3x.yaml \
SOLVER.IMS_PER_BATCH 4 \
OUTPUT_DIR "logs/mask_rcnn_R_50_C4_3x" \
DATASETS.TRAIN "('voucher_train',)" \
DATASETS.TEST "('voucher_val',)" \
DATALOADER.NUM_WORKERS 16 \
INPUT.CROP.SIZE "[1.0, 1.0]" \
MODEL.ROI_HEADS.NUM_CLASSES 10 \
CUDNN_BENCHMARK True

# %%
# !python3 tools/train_net.py \
--num-gpus 2 \
--config-file configs/COCO-InstanceSegmentation/mask_rcnn_R_50_DC5_1x.yaml \
SOLVER.IMS_PER_BATCH 4 \
OUTPUT_DIR "logs/mask_rcnn_R_50_DC5_1x" \
DATASETS.TRAIN "('voucher_train',)" \
DATASETS.TEST "('voucher_val',)" \
DATALOADER.NUM_WORKERS 16 \
INPUT.CROP.SIZE "[1.0, 1.0]" \
MODEL.ROI_HEADS.NUM_CLASSES 10 \
CUDNN_BENCHMARK True

# %%
# !python3 tools/train_net.py \
--num-gpus 2 \
--config-file configs/COCO-InstanceSegmentation/mask_rcnn_R_50_DC5_3x.yaml \
SOLVER.IMS_PER_BATCH 4 \
OUTPUT_DIR "logs/mask_rcnn_R_50_DC5_3x" \
DATASETS.TRAIN "('voucher_train',)" \
DATASETS.TEST "('voucher_val',)" \
DATALOADER.NUM_WORKERS 16 \
INPUT.CROP.SIZE "[1.0, 1.0]" \
MODEL.ROI_HEADS.NUM_CLASSES 10 \
CUDNN_BENCHMARK True

# %%
# !python3 tools/train_net.py \
--num-gpus 2 \
--config-file configs/COCO-InstanceSegmentation/mask_rcnn_R_50_FPN_1x.yaml \
SOLVER.IMS_PER_BATCH 4 \
OUTPUT_DIR "logs/mask_rcnn_R_50_FPN_1x" \
DATASETS.TRAIN "('voucher_train',)" \
DATASETS.TEST "('voucher_val',)" \
DATALOADER.NUM_WORKERS 16 \
INPUT.CROP.SIZE "[1.0, 1.0]" \
MODEL.ROI_HEADS.NUM_CLASSES 10 \
CUDNN_BENCHMARK True
