# %%
# !python3 tools/train_net.py \
--config-file logs/faster_rcnn_R_101_C4_3x/config.yaml \
--eval-only MODEL.WEIGHTS logs/faster_rcnn_R_101_C4_3x/model_0089999.pth
# Out:
# Failed to load OpenCL runtime
# Command Line Args: Namespace(config_file='logs/faster_rcnn_R_101_C4_3x/config.yaml', dist_url='tcp://127.0.0.1:49152', eval_only=True, machine_rank=0, num_gpus=1, num_machines=1, opts=['MODEL.WEIGHTS', 'logs/faster_rcnn_R_101_C4_3x/model_0089999.pth'], resume=False)
# [06/01 05:46:45 detectron2]: Rank of current process: 0. World size: 1
# [06/01 05:46:45 detectron2]: Environment info:
# ------------------------  -------------------------------------------------------------
# sys.platform              linux
# Python                    3.6.9 (default, Nov  7 2019, 10:44:02) [GCC 8.3.0]
# numpy                     1.13.3
# detectron2                0.1.2 @/detectron2_repo/detectron2
# detectron2 compiler       GCC 7.5
# detectron2 CUDA compiler  10.1
# detectron2 arch flags     sm_35, sm_37, sm_50, sm_52, sm_53, sm_60, sm_61, sm_70, sm_75
# DETECTRON2_ENV_MODULE     <not set>
# ...

# %%
# !python3 tools/train_net.py \
--config-file logs/faster_rcnn_R_101_FPN_3x/config.yaml \
--eval-only MODEL.WEIGHTS logs/faster_rcnn_R_101_FPN_3x/model_0089999.pth
# Out:
# Failed to load OpenCL runtime
# Command Line Args: Namespace(config_file='logs/faster_rcnn_R_101_FPN_3x/config.yaml', dist_url='tcp://127.0.0.1:49152', eval_only=True, machine_rank=0, num_gpus=1, num_machines=1, opts=['MODEL.WEIGHTS', 'logs/faster_rcnn_R_101_FPN_3x/model_0089999.pth'], resume=False)
# [06/01 05:52:08 detectron2]: Rank of current process: 0. World size: 1
# [06/01 05:52:09 detectron2]: Environment info:
# ------------------------  -------------------------------------------------------------
# sys.platform              linux
# Python                    3.6.9 (default, Nov  7 2019, 10:44:02) [GCC 8.3.0]
# numpy                     1.13.3
# detectron2                0.1.2 @/detectron2_repo/detectron2
# detectron2 compiler       GCC 7.5
# detectron2 CUDA compiler  10.1
# detectron2 arch flags     sm_35, sm_37, sm_50, sm_52, sm_53, sm_60, sm_61, sm_70, sm_75
# DETECTRON2_ENV_MODULE     <not set>
# ...

# %%
# !python3 tools/train_net.py \
--config-file logs/faster_rcnn_R_50_C4_1x/config.yaml \
--eval-only MODEL.WEIGHTS logs/faster_rcnn_R_50_C4_1x/model_0089999.pth
# Out:
# Failed to load OpenCL runtime
# Command Line Args: Namespace(config_file='logs/faster_rcnn_R_50_C4_1x/config.yaml', dist_url='tcp://127.0.0.1:49152', eval_only=True, machine_rank=0, num_gpus=1, num_machines=1, opts=['MODEL.WEIGHTS', 'logs/faster_rcnn_R_50_C4_1x/model_0089999.pth'], resume=False)
# [06/01 05:54:03 detectron2]: Rank of current process: 0. World size: 1
# [06/01 05:54:03 detectron2]: Environment info:
# ------------------------  -------------------------------------------------------------
# sys.platform              linux
# Python                    3.6.9 (default, Nov  7 2019, 10:44:02) [GCC 8.3.0]
# numpy                     1.13.3
# detectron2                0.1.2 @/detectron2_repo/detectron2
# detectron2 compiler       GCC 7.5
# detectron2 CUDA compiler  10.1
# detectron2 arch flags     sm_35, sm_37, sm_50, sm_52, sm_53, sm_60, sm_61, sm_70, sm_75
# DETECTRON2_ENV_MODULE     <not set>
# PyTorch                   1.5.0 @/usr/local/lib/python3.6/dist-packages/torch
# ...

# %%
# !python3 tools/train_net.py \
--config-file logs/faster_rcnn_R_50_DC5_1x/config.yaml \
--eval-only MODEL.WEIGHTS logs/faster_rcnn_R_50_DC5_1x/model_0089999.pth
# Out:
# Failed to load OpenCL runtime
# Command Line Args: Namespace(config_file='logs/faster_rcnn_R_50_DC5_1x/config.yaml', dist_url='tcp://127.0.0.1:49152', eval_only=True, machine_rank=0, num_gpus=1, num_machines=1, opts=['MODEL.WEIGHTS', 'logs/faster_rcnn_R_50_DC5_1x/model_0089999.pth'], resume=False)
# [06/01 05:59:05 detectron2]: Rank of current process: 0. World size: 1
# [06/01 05:59:06 detectron2]: Environment info:
# ------------------------  -------------------------------------------------------------
# sys.platform              linux
# Python                    3.6.9 (default, Nov  7 2019, 10:44:02) [GCC 8.3.0]
# numpy                     1.13.3
# detectron2                0.1.2 @/detectron2_repo/detectron2
# detectron2 compiler       GCC 7.5
# detectron2 CUDA compiler  10.1
# detectron2 arch flags     sm_35, sm_37, sm_50, sm_52, sm_53, sm_60, sm_61, sm_70, sm_75
# DETECTRON2_ENV_MODULE     <not set>
# ...

# %%
# !python3 tools/train_net.py \
--config-file logs/faster_rcnn_X_101_32x8d_FPN_3x/config.yaml \
--eval-only MODEL.WEIGHTS logs/faster_rcnn_X_101_32x8d_FPN_3x/model_0089999.pth
# Out:
# Failed to load OpenCL runtime
# Command Line Args: Namespace(config_file='logs/faster_rcnn_X_101_32x8d_FPN_3x/config.yaml', dist_url='tcp://127.0.0.1:49152', eval_only=True, machine_rank=0, num_gpus=1, num_machines=1, opts=['MODEL.WEIGHTS', 'logs/faster_rcnn_X_101_32x8d_FPN_3x/model_0089999.pth'], resume=False)
# [06/01 06:01:34 detectron2]: Rank of current process: 0. World size: 1
# [06/01 06:01:34 detectron2]: Environment info:
# ------------------------  -------------------------------------------------------------
# sys.platform              linux
# Python                    3.6.9 (default, Nov  7 2019, 10:44:02) [GCC 8.3.0]
# numpy                     1.13.3
# detectron2                0.1.2 @/detectron2_repo/detectron2
# detectron2 compiler       GCC 7.5
# detectron2 CUDA compiler  10.1
# detectron2 arch flags     sm_35, sm_37, sm_50, sm_52, sm_53, sm_60, sm_61, sm_70, sm_75
# DETECTRON2_ENV_MODULE     <not set>
# ...
